# %% [markdown]
# # Requirements

# %%
from testing_classifier import thread_mapReduce
import os
import glob
import pandas as pd
import h5py
import numpy as np

# %% [markdown]
# # Read CSV

# %%
path = os.getcwd() + "/../Datasets"
csv_files = glob.glob(os.path.join(path, "*.csv"))
csv_dfs = {}
for f in csv_files:
    file_name = f.split("\\")[-1]

    # remove the .csv extension
    file_name = file_name[:-4]

    if file_name == "Amazon-Products":
        continue

    # read the csv file 
    df = pd.read_csv(f)
    csv_dfs[file_name] = df

# %% [markdown]
# # Read embeddings

# %%
def get_embeddings(file_name):
    folder_path = 'images'
    with h5py.File(folder_path + f"/{file_name}.hdf5", 'r') as hdf:
        if "images" in hdf:
            embeddings = hdf["images"][:]
        else:
            embeddings = np.zeros((0, 512))
        return embeddings.copy()

# %%
urls = {file: csv_dfs[file]["image"] for file in csv_dfs}
embeddings = {file: get_embeddings(file) for file in csv_dfs}

# %% [markdown]
# # Evaluation

# %% [markdown]
# ### image input

# %%
input_image = "sunflower/sunflower1.jpg"
emb = np.load("sunflower/sunflower1.npy")

# %%
# display the image
from PIL import Image
import matplotlib.pyplot as plt

img = Image.open(input_image)
plt.imshow(img)

# %% [markdown]
# ### testing

# %%
file_names = [line.strip() for line in open("file_names.txt", "r")]
results = thread_mapReduce(file_names, emb, top_k=10)

# %%
df = pd.DataFrame(columns=file_names)
for csv_result in results:
    csv_name = csv_result[0]
    scores = csv_result[1].flatten()
    indices = csv_result[2].flatten()
    # merge scores and indices to tuple
    maxes = list(zip(indices, scores))
    df[csv_name] = maxes
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[15], line 9
#       6     # merge scores and indices to tuple
#       7     maxes = list(zip(indices, scores))
# ----> 9     df[csv_name] = maxes
#      11 x = 1
#
# File D:\Documents\GitHub\Amazon-Image-matcher\.venv\Lib\site-packages\pandas\core\frame.py:4311, in DataFrame.__setitem__(self, key, value)
#    4308     self._setitem_array([key], value)
#    4309 else:
#    4310     # set column
# -> 4311     self._set_item(key, value)
#
# File D:\Documents\GitHub\Amazon-Image-matcher\.venv\Lib\site-packages\pandas\core\frame.py:4524, in DataFrame._set_item(self, key, value)
#    4514 def _set_item(self, key, value) -> None:
#    4515     """
#    4516     Add series to DataFrame in specified column.
#    4517
#    (...)
#    4522     ensure homogeneity.
#    4523     """
# -> 4524     value, refs = self._sanitize_column(value)
#    4526     if (
#    4527         key in self.columns
#    4528         and value.ndim == 1
#    4529         and not isinstance(value.dtype, ExtensionDtype)
#    4530     ):
#    4531         # broadcast across multiple columns if necessary
#    4532         if not self.columns.is_unique or isinstance(self.columns, MultiIndex):
#
# File D:\Documents\GitHub\Amazon-Image-matcher\.venv\Lib\site-packages\pandas\core\frame.py:5266, in DataFrame._sanitize_column(self, value)
#    5263     return _reindex_for_setitem(value, self.index)
#    5265 if is_list_like(value):
# -> 5266     com.require_length_match(value, self.index)
#    5267 arr = sanitize_array(value, self.index, copy=True, allow_2d=True)
#    5268 if (
#    5269     isinstance(value, Index)
#    5270     and value.dtype == "object"
#    (...)
#    5273     # TODO: Remove kludge in sanitize_array for string mode when enforcing
#    5274     # this deprecation
#
# File D:\Documents\GitHub\Amazon-Image-matcher\.venv\Lib\site-packages\pandas\core\common.py:573, in require_length_match(data, index)
#     569 """
#     570 Check the length of data matches the length of the index.
#     571 """
#     572 if len(data) != len(index):
# --> 573     raise ValueError(
#     574         "Length of values "
#     575         f"({len(data)}) "
#     576         "does not match length of index "
#     577         f"({len(index)})"
#     578     )
#
# ValueError: Length of values (1) does not match length of index (10)

# %%
for csv_result in results:
    csv_name = csv_result[0]
    print(f"Results for {csv_name}")
    scores = csv_result[1]
    indices = csv_result[2]
    for i in range(csv_result[1].shape[0]):
        print(f"csv index: {indices[i]} score: {scores[i]}")
# Out:
# Results for Headphones
# csv index: [0] score: [-0.36552322]
# csv index: [0] score: [-0.39303127]
# csv index: [0] score: [-0.38049716]
# csv index: [0] score: [-0.38049716]
# csv index: [0] score: [-0.28835663]
# csv index: [0] score: [-0.319358]
# csv index: [0] score: [-0.35872987]
# csv index: [0] score: [-0.36411545]
# csv index: [0] score: [-0.36289775]
# csv index: [0] score: [-0.39940363]
# Results for Baby Fashion
# csv index: [0] score: [-0.35183543]
# csv index: [0] score: [-0.5260769]
# csv index: [0] score: [-0.33141702]
# csv index: [0] score: [-0.44060022]
# csv index: [0] score: [-0.46012634]
# csv index: [0] score: [-0.40873754]
# csv index: [0] score: [-0.39903826]
# csv index: [0] score: [-0.41085202]
# csv index: [0] score: [-0.50188696]
# csv index: [0] score: [-0.40903494]
# Results for Camping and Hiking
# csv index: [0] score: [-0.44409376]
# csv index: [0] score: [-0.32957762]
# csv index: [0] score: [-0.38868847]
# csv index: [0] score: [-0.43614805]
# csv index: [0] score: [-0.3952375]
# csv index: [0] score: [-0.3977235]
# csv index: [0] score: [-0.35487428]
# csv index: [0] score: [-0.39696637]
# csv index: [0] score: [-0.4016695]
# csv index: [0] score: [-0.41245547]
# Results for School Bags
# csv index: [0] score: [-0.]
# csv index: [0] score: [-0.]
# csv index: [0] score: [-0.]
# csv index: [0] score: [-0.]
# csv index: [0] score: [-0.]
# csv index: [0] score: [-0.]
# csv index: [0] score: [-0.]
# csv index: [0] score: [-0.]
# csv index: [0] score: [-0.]
# csv index: [0] score: [-0.]
# Results for Health and Personal Care
# csv index: [0] score: [-0.3607799]
# csv index: [0] score: [-0.34421918]
# csv index: [0] score: [-0.34897077]
# csv index: [0] score: [-0.33650222]
# csv index: [0] score: [-0.35126975]
# csv index: [0] score: [-0.416004]
# csv index: [0] score: [-0.37038943]
# csv index: [0] score: [-0.40931952]
# csv index: [0] score: [-0.35197118]
# csv index: [0] score: [-0.3604202]
# Results for School Textbooks
# csv index: 0 score: -0.0
# Results for Heating and Cooling Appliances
# csv index: [0] score: [-0.]
# csv index: [0] score: [-0.]
# csv index: [0] score: [-0.]
# csv index: [0] score: [-0.]
# csv index: [0] score: [-0.]
# csv index: [0] score: [-0.]
# csv index: [0] score: [-0.]
# csv index: [0] score: [-0.]
# csv index: [0] score: [-0.]
# csv index: [0] score: [-0.]
# Results for Security Cameras
# csv index: [0] score: [-0.]
# csv index: [0] score: [-0.]
# csv index: [0] score: [-0.]
# csv index: [0] score: [-0.]
# csv index: [0] score: [-0.]
# csv index: [0] score: [-0.]
# csv index: [0] score: [-0.]
# csv index: [0] score: [-0.]
# csv index: [0] score: [-0.]
# csv index: [0] score: [-0.]
# Results for Home Audio and Theater
# csv index: [0] score: [-0.273206]
# csv index: [0] score: [-0.2689622]
# csv index: [0] score: [-0.36449626]
# csv index: [0] score: [-0.35057974]
# csv index: [0] score: [-0.37886673]
# csv index: [0] score: [-0.3086487]
# csv index: [0] score: [-0.3257501]
# csv index: [0] score: [-0.40001154]
# csv index: [0] score: [-0.32778808]
# csv index: [0] score: [-0.38342643]
# Results for Sewing and Craft Supplies
# csv index: [0] score: [-0.36002234]
# csv index: [0] score: [-0.4186674]
# csv index: [0] score: [-0.35910302]
# csv index: [0] score: [-0.37005427]
# csv index: [0] score: [-0.29864714]
# csv index: [0] score: [-0.3385667]
# csv index: [0] score: [-0.4704957]
# csv index: [0] score: [-0.49674785]
# csv index: [0] score: [-0.34818703]
# csv index: [0] score: [-0.45846704]
# Results for Home Dcor
# csv index: [0] score: [-0.3965634]
# csv index: [0] score: [-0.31265458]
# csv index: [0] score: [-0.34612718]
# csv index: [0] score: [-0.44624397]
# csv index: [0] score: [-0.4603565]
# csv index: [0] score: [-0.4636151]
# csv index: [0] score: [-0.34834838]
# csv index: [0] score: [-0.34907436]
# csv index: [0] score: [-0.39442623]
# csv index: [0] score: [-0.3824799]
# Results for Baby Products
# csv index: [0] score: [-0.394646]
# csv index: [0] score: [-0.4200303]
# csv index: [0] score: [-0.4333459]
# csv index: [0] score: [-0.52551717]
# csv index: [0] score: [-0.43244004]
# csv index: [0] score: [-0.4694785]
# csv index: [0] score: [-0.4443485]
# csv index: [0] score: [-0.33205605]
# csv index: [0] score: [-0.45479897]
# csv index: [0] score: [-0.44943246]
# Results for Shirts
# csv index: [0] score: [-0.]
# csv index: [0] score: [-0.]
# csv index: [0] score: [-0.]
# csv index: [0] score: [-0.]
# csv index: [0] score: [-0.]
# csv index: [0] score: [-0.]
# csv index: [0] score: [-0.]
# csv index: [0] score: [-0.]
# csv index: [0] score: [-0.]
# csv index: [0] score: [-0.]
# Results for Car Accessories
# csv index: [0] score: [-0.38780254]
# csv index: [0] score: [-0.37387183]
# csv index: [0] score: [-0.37191707]
# csv index: [0] score: [-0.38810956]
# csv index: [0] score: [-0.35789597]
# csv index: [0] score: [-0.35778892]
# csv index: [0] score: [-0.3651556]
# csv index: [0] score: [-0.41770822]
# csv index: [0] score: [-0.4028324]
# csv index: [0] score: [-0.33390522]
# Results for Home Entertainment Systems
# csv index: [0] score: [-0.40466717]
# csv index: [0] score: [-0.40422064]
# csv index: [0] score: [-0.2850475]
# csv index: [0] score: [-0.34838423]
# csv index: [0] score: [-0.36168134]
# csv index: [0] score: [-0.268314]
# csv index: [0] score: [-0.33416182]
# csv index: [0] score: [-0.38698736]
# csv index: [0] score: [-0.34344828]
# csv index: [0] score: [-0.32205316]
# Results for All Hindi
# csv index: 0 score: -0.0
# Results for Shoes
# csv index: [0] score: [-0.33298832]
# csv index: [0] score: [-0.37076485]
# csv index: [0] score: [-0.37093076]
# csv index: [0] score: [-0.39690623]
# csv index: [0] score: [-0.4174018]
# csv index: [0] score: [-0.40665787]
# csv index: [0] score: [-0.37208384]
# csv index: [0] score: [-0.3917204]
# csv index: [0] score: [-0.35974902]
# csv index: [0] score: [-0.3821928]
# Results for Home Furnishing
# csv index: [0] score: [-0.35274047]
# csv index: [0] score: [-0.41408634]
# csv index: [0] score: [-0.38882834]
# csv index: [0] score: [-0.44844207]
# csv index: [0] score: [-0.39201462]
# csv index: [0] score: [-0.40834206]
# csv index: [0] score: [-0.3650765]
# csv index: [0] score: [-0.37998667]
# csv index: [0] score: [-0.41878605]
# csv index: [0] score: [-0.3994055]
# Results for Snack Foods
# csv index: [0] score: [-0.37916565]
# csv index: [0] score: [-0.41617686]
# csv index: [0] score: [-0.42068487]
# csv index: [0] score: [-0.4009259]
# csv index: [0] score: [-0.3629523]
# csv index: [0] score: [-0.25820774]
# csv index: [0] score: [-0.28287625]
# csv index: [0] score: [-0.36218625]
# csv index: [0] score: [-0.39933714]
# csv index: [0] score: [-0.4684931]
# Results for All English
# csv index: 0 score: -0.0
# Results for Home Improvement
# csv index: [0] score: [-0.]
# csv index: [0] score: [-0.]
# csv index: [0] score: [-0.]
# csv index: [0] score: [-0.]
# csv index: [0] score: [-0.]
# csv index: [0] score: [-0.]
# csv index: [0] score: [-0.]
# csv index: [0] score: [-0.]
# csv index: [0] score: [-0.]
# csv index: [0] score: [-0.]
# Results for Speakers
# csv index: [0] score: [-0.]
# csv index: [0] score: [-0.]
# csv index: [0] score: [-0.]
# csv index: [0] score: [-0.]
# csv index: [0] score: [-0.]
# csv index: [0] score: [-0.]
# csv index: [0] score: [-0.]
# csv index: [0] score: [-0.]
# csv index: [0] score: [-0.]
# csv index: [0] score: [-0.]
# Results for Backpacks
# csv index: [0] score: [-0.]
# csv index: [0] score: [-0.]
# csv index: [0] score: [-0.]
# csv index: [0] score: [-0.]
# csv index: [0] score: [-0.]
# csv index: [0] score: [-0.]
# csv index: [0] score: [-0.]
# csv index: [0] score: [-0.]
# csv index: [0] score: [-0.]
# csv index: [0] score: [-0.]
# Results for Home Storage
# csv index: [0] score: [-0.]
# csv index: [0] score: [-0.]
# csv index: [0] score: [-0.]
# csv index: [0] score: [-0.]
# csv index: [0] score: [-0.]
# csv index: [0] score: [-0.]
# csv index: [0] score: [-0.]
# csv index: [0] score: [-0.]
# csv index: [0] score: [-0.]
# csv index: [0] score: [-0.]
# Results for All Exercise and Fitness
# csv index: [0] score: [-0.40686214]
# csv index: [0] score: [-0.38977575]
# csv index: [0] score: [-0.43980032]
# csv index: [0] score: [-0.39701617]
# csv index: [0] score: [-0.40119392]
# csv index: [0] score: [-0.4184035]
# csv index: [0] score: [-0.43956217]
# csv index: [0] score: [-0.38435555]
# csv index: [0] score: [-0.38339967]
# csv index: [0] score: [-0.29667607]
# Results for Car and Bike Care
# csv index: [0] score: [-0.]
# csv index: [0] score: [-0.]
# csv index: [0] score: [-0.]
# csv index: [0] score: [-0.]
# csv index: [0] score: [-0.]
# csv index: [0] score: [-0.]
# csv index: [0] score: [-0.]
# csv index: [0] score: [-0.]
# csv index: [0] score: [-0.]
# csv index: [0] score: [-0.]
# Results for Sports Collectibles
# csv index: 0 score: -0.0
# Results for Household Supplies
# csv index: [0] score: [-0.]
# csv index: [0] score: [-0.]
# csv index: [0] score: [-0.]
# csv index: [0] score: [-0.]
# csv index: [0] score: [-0.]
# csv index: [0] score: [-0.]
# csv index: [0] score: [-0.]
# csv index: [0] score: [-0.]
# csv index: [0] score: [-0.]
# csv index: [0] score: [-0.]
# Results for Sports Shoes
# csv index: [0] score: [-0.34371477]
# csv index: [0] score: [-0.35780406]
# csv index: [0] score: [-0.35827562]
# csv index: [0] score: [-0.37623766]
# csv index: [0] score: [-0.37232247]
# csv index: [0] score: [-0.3936497]
# csv index: [0] score: [-0.35498083]
# csv index: [0] score: [-0.3873396]
# csv index: [0] score: [-0.37610254]
# csv index: [0] score: [-0.40150443]
# Results for Indian Classical
# csv index: 0 score: -0.0
# Results for Air Conditioners
# csv index: [0] score: [-0.35239893]
# csv index: [0] score: [-0.40796167]
# csv index: [0] score: [-0.18545344]
# csv index: [0] score: [-0.44393286]
# csv index: [0] score: [-0.34463698]
# csv index: [0] score: [-0.41890275]
# csv index: [0] score: [-0.397641]
# csv index: [0] score: [-0.39678848]
# csv index: [0] score: [-0.3721249]
# csv index: [0] score: [-0.3707209]
# Results for All Books
# csv index: 0 score: -0.0
# Results for Sportswear
# csv index: [0] score: [-0.32517606]
# csv index: [0] score: [-0.38847286]
# csv index: [0] score: [-0.39661667]
# csv index: [0] score: [-0.39661667]
# csv index: [0] score: [-0.39661667]
# csv index: [0] score: [-0.4653517]
# csv index: [0] score: [-0.40695328]
# csv index: [0] score: [-0.33863103]
# csv index: [0] score: [-0.37973282]
# csv index: [0] score: [-0.41292804]
# Results for Indian Language Books
# csv index: 0 score: -0.0
# Results for All Home and Kitchen
# csv index: [0] score: [-0.41808856]
# csv index: [0] score: [-0.28402278]
# csv index: [0] score: [-0.37821722]
# csv index: [0] score: [-0.33699974]
# csv index: [0] score: [-0.3440187]
# csv index: [0] score: [-0.3426774]
# csv index: [0] score: [-0.43693238]
# csv index: [0] score: [-0.47008306]
# csv index: [0] score: [-0.32602805]
# csv index: [0] score: [-0.38946426]
# Results for STEM Toys Store
# csv index: [0] score: [-0.]
# csv index: [0] score: [-0.]
# csv index: [0] score: [-0.]
# csv index: [0] score: [-0.]
# csv index: [0] score: [-0.]
# csv index: [0] score: [-0.]
# csv index: [0] score: [-0.]
# csv index: [0] score: [-0.]
# csv index: [0] score: [-0.]
# csv index: [0] score: [-0.]
# Results for Badminton
# csv index: [0] score: [-0.32582366]
# csv index: [0] score: [-0.32582366]
# csv index: [0] score: [-0.32582366]
# csv index: [0] score: [-0.32582366]
# csv index: [0] score: [-0.32582366]
# csv index: [0] score: [-0.32582366]
# csv index: [0] score: [-0.32582366]
# csv index: [0] score: [-0.32582366]
# csv index: [0] score: [-0.32582366]
# csv index: [0] score: [-0.32582366]
# Results for Indoor Lighting
# csv index: [0] score: [-0.39491117]
# csv index: [0] score: [-0.2737287]
# csv index: [0] score: [-0.3065763]
# csv index: [0] score: [-0.32212168]
# csv index: [0] score: [-0.31978434]
# csv index: [0] score: [-0.2558967]
# csv index: [0] score: [-0.4028768]
# csv index: [0] score: [-0.30448738]
# csv index: [0] score: [-0.24203837]
# csv index: [0] score: [-0.43295842]
# Results for Car Electronics
# csv index: [0] score: [-0.27924904]
# csv index: [0] score: [-0.3311818]
# csv index: [0] score: [-0.3311818]
# csv index: [0] score: [-0.33278376]
# csv index: [0] score: [-0.37458575]
# csv index: [0] score: [-0.24796769]
# csv index: [0] score: [-0.33699107]
# csv index: [0] score: [-0.36473224]
# csv index: [0] score: [-0.36775503]
# csv index: [0] score: [-0.39177465]
# Results for Strength Training
# csv index: [0] score: [-0.40125087]
# csv index: [0] score: [-0.29622436]
# csv index: [0] score: [-0.36985722]
# csv index: [0] score: [-0.33154535]
# csv index: [0] score: [-0.28646398]
# csv index: [0] score: [-0.39342695]
# csv index: [0] score: [-0.40219137]
# csv index: [0] score: [-0.40247893]
# csv index: [0] score: [-0.33929044]
# csv index: [0] score: [-0.44882882]
# Results for Industrial and Scientific Supplies
# csv index: [0] score: [-0.32760644]
# csv index: [0] score: [-0.35373047]
# csv index: [0] score: [-0.32753134]
# csv index: [0] score: [-0.41580588]
# csv index: [0] score: [-0.33140975]
# csv index: [0] score: [-0.46323758]
# csv index: [0] score: [-0.34710515]
# csv index: [0] score: [-0.3232311]
# csv index: [0] score: [-0.37208813]
# csv index: [0] score: [-0.31962666]
# Results for Car Parts
# csv index: [0] score: [-0.]
# csv index: [0] score: [-0.]
# csv index: [0] score: [-0.]
# csv index: [0] score: [-0.]
# csv index: [0] score: [-0.]
# csv index: [0] score: [-0.]
# csv index: [0] score: [-0.]
# csv index: [0] score: [-0.]
# csv index: [0] score: [-0.]
# csv index: [0] score: [-0.]
# Results for Strollers and Prams
# csv index: [0] score: [-0.37340355]
# csv index: [0] score: [-0.37400034]
# csv index: [0] score: [-0.3968041]
# csv index: [0] score: [-0.41392547]
# csv index: [0] score: [-0.36388326]
# csv index: [0] score: [-0.32921004]
# csv index: [0] score: [-0.4126775]
# csv index: [0] score: [-0.28858882]
# csv index: [0] score: [-0.36391413]
# csv index: [0] score: [-0.31137872]
# Results for Innerwear
# csv index: [0] score: [-0.3530726]
# csv index: [0] score: [-0.36482167]
# csv index: [0] score: [-0.37951708]
# csv index: [0] score: [-0.38996628]
# csv index: [0] score: [-0.4110184]
# csv index: [0] score: [-0.3662572]
# csv index: [0] score: [-0.38550723]
# csv index: [0] score: [-0.3930272]
# csv index: [0] score: [-0.41282976]
# csv index: [0] score: [-0.45626318]
# Results for All Movies and TV Shows
# csv index: 0 score: -0.0
# Results for Cardio Equipment
# csv index: [0] score: [-0.]
# csv index: [0] score: [-0.]
# csv index: [0] score: [-0.]
# csv index: [0] score: [-0.]
# csv index: [0] score: [-0.]
# csv index: [0] score: [-0.]
# csv index: [0] score: [-0.]
# csv index: [0] score: [-0.]
# csv index: [0] score: [-0.]
# csv index: [0] score: [-0.]
# Results for Subscribe and Save
# csv index: 0 score: -0.0
# Results for International Music
# csv index: 0 score: -0.0
# Results for Bags and Luggage
# csv index: [0] score: [-0.37571898]
# csv index: [0] score: [-0.3466489]
# csv index: [0] score: [-0.35798275]
# csv index: [0] score: [-0.3547457]
# csv index: [0] score: [-0.37921524]
# csv index: [0] score: [-0.41243103]
# csv index: [0] score: [-0.32200655]
# csv index: [0] score: [-0.3213718]
# csv index: [0] score: [-0.38120383]
# csv index: [0] score: [-0.2611185]
# Results for Casual Shoes
# csv index: [0] score: [-0.]
# csv index: [0] score: [-0.]
# csv index: [0] score: [-0.]
# csv index: [0] score: [-0.]
# csv index: [0] score: [-0.]
# csv index: [0] score: [-0.]
# csv index: [0] score: [-0.]
# csv index: [0] score: [-0.]
# csv index: [0] score: [-0.]
# csv index: [0] score: [-0.]
# Results for Suitcases and Trolley Bags
# csv index: [0] score: [-0.37897217]
# csv index: [0] score: [-0.37457448]
# csv index: [0] score: [-0.30740732]
# csv index: [0] score: [-0.34201407]
# csv index: [0] score: [-0.3283502]
# csv index: [0] score: [-0.30756414]
# csv index: [0] score: [-0.36634547]
# csv index: [0] score: [-0.34369403]
# csv index: [0] score: [-0.25437438]
# csv index: [0] score: [-0.356911]
# Results for International Toy Store
# csv index: [0] score: [-0.]
# csv index: [0] score: [-0.]
# csv index: [0] score: [-0.]
# csv index: [0] score: [-0.]
# csv index: [0] score: [-0.]
# csv index: [0] score: [-0.]
# csv index: [0] score: [-0.]
# csv index: [0] score: [-0.]
# csv index: [0] score: [-0.]
# csv index: [0] score: [-0.]
# Results for All Grocery and Gourmet Foods
# csv index: [0] score: [-0.29960003]
# csv index: [0] score: [-0.31126544]
# csv index: [0] score: [-0.373356]
# csv index: [0] score: [-0.4303544]
# csv index: [0] score: [-0.342404]
# csv index: [0] score: [-0.36057624]
# csv index: [0] score: [-0.2938537]
# csv index: [0] score: [-0.3292431]
# csv index: [0] score: [-0.42323104]
# csv index: [0] score: [-0.31372467]
# Results for Childrens Books
# csv index: 0 score: -0.0
# Results for Sunglasses
# csv index: [0] score: [-0.]
# csv index: [0] score: [-0.]
# csv index: [0] score: [-0.]
# csv index: [0] score: [-0.]
# csv index: [0] score: [-0.]
# csv index: [0] score: [-0.]
# csv index: [0] score: [-0.]
# csv index: [0] score: [-0.]
# csv index: [0] score: [-0.]
# csv index: [0] score: [-0.]
# Results for All Electronics
# csv index: [0] score: [-0.]
# csv index: [0] score: [-0.]
# csv index: [0] score: [-0.]
# csv index: [0] score: [-0.]
# csv index: [0] score: [-0.]
# csv index: [0] score: [-0.]
# csv index: [0] score: [-0.]
# csv index: [0] score: [-0.]
# csv index: [0] score: [-0.]
# csv index: [0] score: [-0.]
# Results for Janitorial and Sanitation Supplies
# csv index: [0] score: [-0.31654093]
# csv index: [0] score: [-0.41455185]
# csv index: [0] score: [-0.37041253]
# csv index: [0] score: [-0.3163815]
# csv index: [0] score: [-0.49966663]
# csv index: [0] score: [-0.4129842]
# csv index: [0] score: [-0.41161144]
# csv index: [0] score: [-0.3611813]
# csv index: [0] score: [-0.43865633]
# csv index: [0] score: [-0.33542004]
# Results for Clothing
# csv index: [0] score: [-0.]
# csv index: [0] score: [-0.]
# csv index: [0] score: [-0.]
# csv index: [0] score: [-0.]
# csv index: [0] score: [-0.]
# csv index: [0] score: [-0.]
# csv index: [0] score: [-0.]
# csv index: [0] score: [-0.]
# csv index: [0] score: [-0.]
# csv index: [0] score: [-0.]
# Results for T-shirts and Polos
# csv index: [0] score: [-0.]
# csv index: [0] score: [-0.]
# csv index: [0] score: [-0.]
# csv index: [0] score: [-0.]
# csv index: [0] score: [-0.]
# csv index: [0] score: [-0.]
# csv index: [0] score: [-0.]
# csv index: [0] score: [-0.]
# csv index: [0] score: [-0.]
# csv index: [0] score: [-0.]
# Results for All Music
# csv index: 0 score: -0.0
# Results for Jeans
# csv index: [0] score: [-0.38004825]
# csv index: [0] score: [-0.36266825]
# csv index: [0] score: [-0.47514]
# csv index: [0] score: [-0.41659877]
# csv index: [0] score: [-0.368292]
# csv index: [0] score: [-0.36963946]
# csv index: [0] score: [-0.35669464]
# csv index: [0] score: [-0.41659877]
# csv index: [0] score: [-0.35669464]
# csv index: [0] score: [-0.40887737]
# Results for Coffee Tea and Beverages
# csv index: [0] score: [-0.440729]
# csv index: [0] score: [-0.35848647]
# csv index: [0] score: [-0.34967592]
# csv index: [0] score: [-0.3968671]
# csv index: [0] score: [-0.357656]
# csv index: [0] score: [-0.32602715]
# csv index: [0] score: [-0.404205]
# csv index: [0] score: [-0.36691484]
# csv index: [0] score: [-0.345156]
# csv index: [0] score: [-0.338089]
# Results for Televisions
# csv index: [0] score: [-0.43881574]
# csv index: [0] score: [-0.4114076]
# csv index: [0] score: [-0.32531846]
# csv index: [0] score: [-0.3055122]
# csv index: [0] score: [-0.40644515]
# csv index: [0] score: [-0.40644515]
# csv index: [0] score: [-0.37920237]
# csv index: [0] score: [-0.4136644]
# csv index: [0] score: [-0.41189712]
# csv index: [0] score: [-0.34848142]
# Results for Jewellery
# csv index: [0] score: [-0.29877403]
# csv index: [0] score: [-0.4496682]
# csv index: [0] score: [-0.40032685]
# csv index: [0] score: [-0.44585148]
# csv index: [0] score: [-0.3473652]
# csv index: [0] score: [-0.38605428]
# csv index: [0] score: [-0.35195723]
# csv index: [0] score: [-0.26868945]
# csv index: [0] score: [-0.28260368]
# csv index: [0] score: [-0.37607226]
# Results for Ballerinas
# csv index: [0] score: [-0.]
# csv index: [0] score: [-0.]
# csv index: [0] score: [-0.]
# csv index: [0] score: [-0.]
# csv index: [0] score: [-0.]
# csv index: [0] score: [-0.]
# csv index: [0] score: [-0.]
# csv index: [0] score: [-0.]
# csv index: [0] score: [-0.]
# csv index: [0] score: [-0.]
# Results for Cricket
# csv index: [0] score: [-0.33257192]
# csv index: [0] score: [-0.4654761]
# csv index: [0] score: [-0.4652013]
# csv index: [0] score: [-0.37818676]
# csv index: [0] score: [-0.40070426]
# csv index: [0] score: [-0.47141472]
# csv index: [0] score: [-0.40638942]
# csv index: [0] score: [-0.3908809]
# csv index: [0] score: [-0.5223998]
# csv index: [0] score: [-0.39800596]
# Results for Test Measure and Inspect
# csv index: [0] score: [-0.]
# csv index: [0] score: [-0.]
# csv index: [0] score: [-0.]
# csv index: [0] score: [-0.]
# csv index: [0] score: [-0.]
# csv index: [0] score: [-0.]
# csv index: [0] score: [-0.]
# csv index: [0] score: [-0.]
# csv index: [0] score: [-0.]
# csv index: [0] score: [-0.]
# Results for Kids Clothing
# csv index: [0] score: [-0.4226027]
# csv index: [0] score: [-0.436796]
# csv index: [0] score: [-0.3377366]
# csv index: [0] score: [-0.4501441]
# csv index: [0] score: [-0.42587078]
# csv index: [0] score: [-0.40507436]
# csv index: [0] score: [-0.44403374]
# csv index: [0] score: [-0.43629545]
# csv index: [0] score: [-0.36624882]
# csv index: [0] score: [-0.37844437]
# Results for Textbooks
# csv index: 0 score: -0.0
# Results for Cycling
# csv index: [0] score: [-0.40527982]
# csv index: [0] score: [-0.46186653]
# csv index: [0] score: [-0.40544555]
# csv index: [0] score: [-0.36985102]
# csv index: [0] score: [-0.29780334]
# csv index: [0] score: [-0.42285895]
# csv index: [0] score: [-0.4072324]
# csv index: [0] score: [-0.33404338]
# csv index: [0] score: [-0.36389482]
# csv index: [0] score: [-0.3817941]
# Results for Kids Fashion
# csv index: [0] score: [-0.]
# csv index: [0] score: [-0.]
# csv index: [0] score: [-0.]
# csv index: [0] score: [-0.]
# csv index: [0] score: [-0.]
# csv index: [0] score: [-0.]
# csv index: [0] score: [-0.]
# csv index: [0] score: [-0.]
# csv index: [0] score: [-0.]
# csv index: [0] score: [-0.]
# Results for All Pet Supplies
# csv index: [0] score: [-0.44987777]
# csv index: [0] score: [-0.47222272]
# csv index: [0] score: [-0.39849305]
# csv index: [0] score: [-0.36572227]
# csv index: [0] score: [-0.37150913]
# csv index: [0] score: [-0.35855025]
# csv index: [0] score: [-0.39838558]
# csv index: [0] score: [-0.37453297]
# csv index: [0] score: [-0.42314714]
# csv index: [0] score: [-0.40447286]
# Results for Diapers
# csv index: [0] score: [-0.]
# csv index: [0] score: [-0.]
# csv index: [0] score: [-0.]
# csv index: [0] score: [-0.]
# csv index: [0] score: [-0.]
# csv index: [0] score: [-0.]
# csv index: [0] score: [-0.]
# csv index: [0] score: [-0.]
# csv index: [0] score: [-0.]
# csv index: [0] score: [-0.]
# Results for The Designer Boutique
# csv index: [0] score: [-0.32474998]
# csv index: [0] score: [-0.35363078]
# csv index: [0] score: [-0.40203476]
# csv index: [0] score: [-0.38748097]
# csv index: [0] score: [-0.37692845]
# csv index: [0] score: [-0.38888475]
# csv index: [0] score: [-0.41390526]
# csv index: [0] score: [-0.43846524]
# csv index: [0] score: [-0.41971534]
# csv index: [0] score: [-0.36853313]
# Results for Kids Shoes
# csv index: [0] score: [-0.38071674]
# csv index: [0] score: [-0.3975836]
# csv index: [0] score: [-0.36264563]
# csv index: [0] score: [-0.3697822]
# csv index: [0] score: [-0.36989325]
# csv index: [0] score: [-0.4069941]
# csv index: [0] score: [-0.3673398]
# csv index: [0] score: [-0.3807483]
# csv index: [0] score: [-0.36989325]
# csv index: [0] score: [-0.33018696]
# Results for Diet and Nutrition
# csv index: [0] score: [-0.4618916]
# csv index: [0] score: [-0.37092954]
# csv index: [0] score: [-0.29160413]
# csv index: [0] score: [-0.35146573]
# csv index: [0] score: [-0.36127654]
# csv index: [0] score: [-0.3296306]
# csv index: [0] score: [-0.36217165]
# csv index: [0] score: [-0.35011506]
# csv index: [0] score: [-0.34215933]
# csv index: [0] score: [-0.3178964]
# Results for Toys and Games
# csv index: [0] score: [-0.]
# csv index: [0] score: [-0.]
# csv index: [0] score: [-0.]
# csv index: [0] score: [-0.]
# csv index: [0] score: [-0.]
# csv index: [0] score: [-0.]
# csv index: [0] score: [-0.]
# csv index: [0] score: [-0.]
# csv index: [0] score: [-0.]
# csv index: [0] score: [-0.]
# Results for Beauty and Grooming
# csv index: [0] score: [-0.350396]
# csv index: [0] score: [-0.3898108]
# csv index: [0] score: [-0.46156007]
# csv index: [0] score: [-0.5446373]
# csv index: [0] score: [-0.5896817]
# csv index: [0] score: [-0.40603635]
# csv index: [0] score: [-0.28871125]
# csv index: [0] score: [-0.35313103]
# csv index: [0] score: [-0.30545968]
# csv index: [0] score: [-0.35294586]
# Results for Kids Watches
# csv index: [0] score: [-0.32858646]
# csv index: [0] score: [-0.32858646]
# csv index: [0] score: [-0.32858646]
# csv index: [0] score: [-0.32858646]
# csv index: [0] score: [-0.32858646]
# csv index: [0] score: [-0.32858646]
# csv index: [0] score: [-0.32858646]
# csv index: [0] score: [-0.32858646]
# csv index: [0] score: [-0.32858646]
# csv index: [0] score: [-0.32858646]
# Results for Dog supplies
# csv index: [0] score: [-0.4095366]
# csv index: [0] score: [-0.34958684]
# csv index: [0] score: [-0.36412853]
# csv index: [0] score: [-0.37372226]
# csv index: [0] score: [-0.39719987]
# csv index: [0] score: [-0.30788383]
# csv index: [0] score: [-0.38983008]
# csv index: [0] score: [-0.38808882]
# csv index: [0] score: [-0.4655057]
# csv index: [0] score: [-0.3240702]
# Results for Toys Gifting Store
# csv index: [0] score: [-0.37801808]
# csv index: [0] score: [-0.37699282]
# csv index: [0] score: [-0.4073158]
# csv index: [0] score: [-0.41888496]
# csv index: [0] score: [-0.39755386]
# csv index: [0] score: [-0.3160398]
# csv index: [0] score: [-0.38056532]
# csv index: [0] score: [-0.4319146]
# csv index: [0] score: [-0.41472122]
# csv index: [0] score: [-0.37422088]
# Results for Kindle eBooks
# csv index: 0 score: -0.0
# Results for Entertainment Collectibles
# csv index: 0 score: -0.0
# Results for Travel Accessories
# csv index: [0] score: [-0.33443627]
# csv index: [0] score: [-0.41231802]
# csv index: [0] score: [-0.29978594]
# csv index: [0] score: [-0.271361]
# csv index: [0] score: [-0.40126383]
# csv index: [0] score: [-0.384039]
# csv index: [0] score: [-0.31159824]
# csv index: [0] score: [-0.38054696]
# csv index: [0] score: [-0.39497337]
# csv index: [0] score: [-0.24522349]
# Results for All Sports Fitness and Outdoors
# csv index: [0] score: [-0.45013574]
# csv index: [0] score: [-0.4598722]
# csv index: [0] score: [-0.38592172]
# csv index: [0] score: [-0.34282854]
# csv index: [0] score: [-0.39180532]
# csv index: [0] score: [-0.23402719]
# csv index: [0] score: [-0.40899175]
# csv index: [0] score: [-0.34015116]
# csv index: [0] score: [-0.42843276]
# csv index: [0] score: [-0.2703157]
# Results for Kitchen and Dining
# csv index: [0] score: [-0.28035432]
# csv index: [0] score: [-0.4128065]
# csv index: [0] score: [-0.29583493]
# csv index: [0] score: [-0.30706394]
# csv index: [0] score: [-0.35446745]
# csv index: [0] score: [-0.36507806]
# csv index: [0] score: [-0.429939]
# csv index: [0] score: [-0.37072766]
# csv index: [0] score: [-0.40043354]
# csv index: [0] score: [-0.46766624]
# Results for Ethnic Wear
# csv index: [0] score: [-0.46085766]
# csv index: [0] score: [-0.42163444]
# csv index: [0] score: [-0.38792214]
# csv index: [0] score: [-0.38310885]
# csv index: [0] score: [-0.4340607]
# csv index: [0] score: [-0.44161248]
# csv index: [0] score: [-0.41193092]
# csv index: [0] score: [-0.4455682]
# csv index: [0] score: [-0.42251682]
# csv index: [0] score: [-0.41841257]
# Results for Travel Duffles
# csv index: [0] score: [-0.39676517]
# csv index: [0] score: [-0.30592906]
# csv index: [0] score: [-0.33146062]
# csv index: [0] score: [-0.42330807]
# csv index: [0] score: [-0.40907222]
# csv index: [0] score: [-0.4023623]
# csv index: [0] score: [-0.36932188]
# csv index: [0] score: [-0.37226194]
# csv index: [0] score: [-0.38057205]
# csv index: [0] score: [-0.40768394]
# Results for Kitchen and Home Appliances
# csv index: [0] score: [-0.34229147]
# csv index: [0] score: [-0.36620593]
# csv index: [0] score: [-0.31369686]
# csv index: [0] score: [-0.3166902]
# csv index: [0] score: [-0.3420393]
# csv index: [0] score: [-0.36119342]
# csv index: [0] score: [-0.36016542]
# csv index: [0] score: [-0.2976371]
# csv index: [0] score: [-0.42555007]
# csv index: [0] score: [-0.31219995]
# Results for Exam Central
# csv index: 0 score: -0.0
# Results for Value Bazaar
# csv index: [0] score: [-0.32801574]
# csv index: [0] score: [-0.3351639]
# csv index: [0] score: [-0.39218426]
# csv index: [0] score: [-0.37596637]
# csv index: [0] score: [-0.31672728]
# csv index: [0] score: [-0.35403407]
# csv index: [0] score: [-0.41908342]
# csv index: [0] score: [-0.37063283]
# csv index: [0] score: [-0.39499563]
# csv index: [0] score: [-0.26669714]
# Results for Bedroom Linen
# csv index: [0] score: [-0.4409132]
# csv index: [0] score: [-0.42564183]
# csv index: [0] score: [-0.39193702]
# csv index: [0] score: [-0.43594187]
# csv index: [0] score: [-0.40282166]
# csv index: [0] score: [-0.4151914]
# csv index: [0] score: [-0.4634558]
# csv index: [0] score: [-0.38414747]
# csv index: [0] score: [-0.3865409]
# csv index: [0] score: [-0.34131986]
# Results for Kitchen Storage and Containers
# csv index: [0] score: [-0.]
# csv index: [0] score: [-0.]
# csv index: [0] score: [-0.]
# csv index: [0] score: [-0.]
# csv index: [0] score: [-0.]
# csv index: [0] score: [-0.]
# csv index: [0] score: [-0.]
# csv index: [0] score: [-0.]
# csv index: [0] score: [-0.]
# csv index: [0] score: [-0.]
# Results for Fashion and Silver Jewellery
# csv index: [0] score: [-0.47140896]
# csv index: [0] score: [-0.2811883]
# csv index: [0] score: [-0.42012465]
# csv index: [0] score: [-0.28679958]
# csv index: [0] score: [-0.3815658]
# csv index: [0] score: [-0.4244038]
# csv index: [0] score: [-0.38366735]
# csv index: [0] score: [-0.38770565]
# csv index: [0] score: [-0.26976]
# csv index: [0] score: [-0.32638007]
# Results for Video Games Deals
# csv index: 0 score: -0.0
# Results for Lab and Scientific
# csv index: [0] score: [-0.34020197]
# csv index: [0] score: [-0.26501572]
# csv index: [0] score: [-0.3757795]
# csv index: [0] score: [-0.34233508]
# csv index: [0] score: [-0.37211296]
# csv index: [0] score: [-0.30181104]
# csv index: [0] score: [-0.38662317]
# csv index: [0] score: [-0.37434673]
# csv index: [0] score: [-0.4014613]
# csv index: [0] score: [-0.30001062]
# Results for All Video Games
# csv index: 0 score: -0.0
# Results for Fashion Sales and Deals
# csv index: [0] score: [-0.3130356]
# csv index: [0] score: [-0.33030504]
# csv index: [0] score: [-0.408706]
# csv index: [0] score: [-0.30783948]
# csv index: [0] score: [-0.4022386]
# csv index: [0] score: [-0.40396166]
# csv index: [0] score: [-0.40396166]
# csv index: [0] score: [-0.40396166]
# csv index: [0] score: [-0.4244551]
# csv index: [0] score: [-0.4180141]
# Results for Wallets
# csv index: [0] score: [-0.]
# csv index: [0] score: [-0.]
# csv index: [0] score: [-0.]
# csv index: [0] score: [-0.]
# csv index: [0] score: [-0.]
# csv index: [0] score: [-0.]
# csv index: [0] score: [-0.]
# csv index: [0] score: [-0.]
# csv index: [0] score: [-0.]
# csv index: [0] score: [-0.]
# Results for Lingerie and Nightwear
# csv index: [0] score: [-0.42520174]
# csv index: [0] score: [-0.38312817]
# csv index: [0] score: [-0.45471627]
# csv index: [0] score: [-0.39868316]
# csv index: [0] score: [-0.4793212]
# csv index: [0] score: [-0.44654083]
# csv index: [0] score: [-0.46592814]
# csv index: [0] score: [-0.4118836]
# csv index: [0] score: [-0.43248963]
# csv index: [0] score: [-0.41213563]
# Results for Fashion Sandals
# csv index: [0] score: [-0.]
# csv index: [0] score: [-0.]
# csv index: [0] score: [-0.]
# csv index: [0] score: [-0.]
# csv index: [0] score: [-0.]
# csv index: [0] score: [-0.]
# csv index: [0] score: [-0.]
# csv index: [0] score: [-0.]
# csv index: [0] score: [-0.]
# csv index: [0] score: [-0.]
# Results for Washing Machines
# csv index: [0] score: [-0.]
# csv index: [0] score: [-0.]
# csv index: [0] score: [-0.]
# csv index: [0] score: [-0.]
# csv index: [0] score: [-0.]
# csv index: [0] score: [-0.]
# csv index: [0] score: [-0.]
# csv index: [0] score: [-0.]
# csv index: [0] score: [-0.]
# csv index: [0] score: [-0.]
# Results for Luxury Beauty
# csv index: [0] score: [-0.329264]
# csv index: [0] score: [-0.34044543]
# csv index: [0] score: [-0.33468217]
# csv index: [0] score: [-0.3339295]
# csv index: [0] score: [-0.331339]
# csv index: [0] score: [-0.29765007]
# csv index: [0] score: [-0.38920885]
# csv index: [0] score: [-0.35657993]
# csv index: [0] score: [-0.37796628]
# csv index: [0] score: [-0.34769306]
# Results for All Car and Motorbike Products
# csv index: [0] score: [-0.]
# csv index: [0] score: [-0.]
# csv index: [0] score: [-0.]
# csv index: [0] score: [-0.]
# csv index: [0] score: [-0.]
# csv index: [0] score: [-0.]
# csv index: [0] score: [-0.]
# csv index: [0] score: [-0.]
# csv index: [0] score: [-0.]
# csv index: [0] score: [-0.]
# Results for Fiction Books
# csv index: 0 score: -0.0
# Results for Watches
# csv index: [0] score: [-0.]
# csv index: [0] score: [-0.]
# csv index: [0] score: [-0.]
# csv index: [0] score: [-0.]
# csv index: [0] score: [-0.]
# csv index: [0] score: [-0.]
# csv index: [0] score: [-0.]
# csv index: [0] score: [-0.]
# csv index: [0] score: [-0.]
# csv index: [0] score: [-0.]
# Results for Blu-ray
# csv index: 0 score: -0.0
# Results for Make-up
# csv index: [0] score: [-0.30049875]
# csv index: [0] score: [-0.25791824]
# csv index: [0] score: [-0.3159892]
# csv index: [0] score: [-0.43228072]
# csv index: [0] score: [-0.28288674]
# csv index: [0] score: [-0.32520667]
# csv index: [0] score: [-0.3093463]
# csv index: [0] score: [-0.2837728]
# csv index: [0] score: [-0.38901973]
# csv index: [0] score: [-0.3717156]
# Results for Film Songs
# csv index: 0 score: -0.0
# Results for Western Wear
# csv index: [0] score: [-0.4586537]
# csv index: [0] score: [-0.4314771]
# csv index: [0] score: [-0.38737965]
# csv index: [0] score: [-0.36613914]
# csv index: [0] score: [-0.45850345]
# csv index: [0] score: [-0.4291765]
# csv index: [0] score: [-0.49692667]
# csv index: [0] score: [-0.38507783]
# csv index: [0] score: [-0.38387692]
# csv index: [0] score: [-0.4449146]
# Results for Amazon Fashion
# csv index: [0] score: [-0.44961154]
# csv index: [0] score: [-0.46201777]
# csv index: [0] score: [-0.41144887]
# csv index: [0] score: [-0.44207656]
# csv index: [0] score: [-0.4032812]
# csv index: [0] score: [-0.37110078]
# csv index: [0] score: [-0.4520092]
# csv index: [0] score: [-0.36715803]
# csv index: [0] score: [-0.40478605]
# csv index: [0] score: [-0.3109185]
# Results for Mens Fashion
# csv index: [0] score: [-0.]
# csv index: [0] score: [-0.]
# csv index: [0] score: [-0.]
# csv index: [0] score: [-0.]
# csv index: [0] score: [-0.]
# csv index: [0] score: [-0.]
# csv index: [0] score: [-0.]
# csv index: [0] score: [-0.]
# csv index: [0] score: [-0.]
# csv index: [0] score: [-0.]
# Results for Fine Art
# csv index: 0 score: -0.0
# Results for Womens Fashion
# csv index: [0] score: [-0.36408877]
# csv index: [0] score: [-0.3849986]
# csv index: [0] score: [-0.41048828]
# csv index: [0] score: [-0.4402083]
# csv index: [0] score: [-0.39490575]
# csv index: [0] score: [-0.42384854]
# csv index: [0] score: [-0.41288564]
# csv index: [0] score: [-0.46311438]
# csv index: [0] score: [-0.4821816]
# csv index: [0] score: [-0.41115236]
# Results for Motorbike Accessories and Parts
# csv index: [0] score: [-0.38547376]
# csv index: [0] score: [-0.5558598]
# csv index: [0] score: [-0.3024097]
# csv index: [0] score: [-0.33679014]
# csv index: [0] score: [-0.4258062]
# csv index: [0] score: [-0.30160832]
# csv index: [0] score: [-0.40073577]
# csv index: [0] score: [-0.3670621]
# csv index: [0] score: [-0.20717195]
# csv index: [0] score: [-0.34912133]
# Results for Fitness Accessories
# csv index: [0] score: [-0.38740763]
# csv index: [0] score: [-0.4452968]
# csv index: [0] score: [-0.39695525]
# csv index: [0] score: [-0.34773362]
# csv index: [0] score: [-0.38571978]
# csv index: [0] score: [-0.40369177]
# csv index: [0] score: [-0.32953984]
# csv index: [0] score: [-0.40378726]
# csv index: [0] score: [-0.42132843]
# csv index: [0] score: [-0.36375254]
# Results for Yoga
# csv index: [0] score: [-0.422615]
# csv index: [0] score: [-0.29952413]
# csv index: [0] score: [-0.47230345]
# csv index: [0] score: [-0.43965486]
# csv index: [0] score: [-0.3983551]
# csv index: [0] score: [-0.48512793]
# csv index: [0] score: [-0.39918566]
# csv index: [0] score: [-0.40778905]
# csv index: [0] score: [-0.40778193]
# csv index: [0] score: [-0.3867687]
# Results for Musical Instruments and Professional Audio
# csv index: [0] score: [-0.36159772]
# csv index: [0] score: [-0.25841647]
# csv index: [0] score: [-0.2987002]
# csv index: [0] score: [-0.34138402]
# csv index: [0] score: [-0.33525643]
# csv index: [0] score: [-0.35695693]
# csv index: [0] score: [-0.34325895]
# csv index: [0] score: [-0.33275753]
# csv index: [0] score: [-0.36940646]
# csv index: [0] score: [-0.39454657]
# Results for Football
# csv index: [0] score: [-0.37012434]
# csv index: [0] score: [-0.36005998]
# csv index: [0] score: [-0.41585648]
# csv index: [0] score: [-0.42144614]
# csv index: [0] score: [-0.40547594]
# csv index: [0] score: [-0.3926136]
# csv index: [0] score: [-0.4070301]
# csv index: [0] score: [-0.4163534]
# csv index: [0] score: [-0.44066948]
# csv index: [0] score: [-0.38595527]
# Results for Camera Accessories
# csv index: [0] score: [-0.]
# csv index: [0] score: [-0.]
# csv index: [0] score: [-0.]
# csv index: [0] score: [-0.]
# csv index: [0] score: [-0.]
# csv index: [0] score: [-0.]
# csv index: [0] score: [-0.]
# csv index: [0] score: [-0.]
# csv index: [0] score: [-0.]
# csv index: [0] score: [-0.]
# Results for Nursing and Feeding
# csv index: [0] score: [-0.]
# csv index: [0] score: [-0.]
# csv index: [0] score: [-0.]
# csv index: [0] score: [-0.]
# csv index: [0] score: [-0.]
# csv index: [0] score: [-0.]
# csv index: [0] score: [-0.]
# csv index: [0] score: [-0.]
# csv index: [0] score: [-0.]
# csv index: [0] score: [-0.]
# Results for Amazon Pharmacy
# csv index: 0 score: -0.0
# Results for Formal Shoes
# csv index: [0] score: [-0.29697335]
# csv index: [0] score: [-0.31725103]
# csv index: [0] score: [-0.29697335]
# csv index: [0] score: [-0.29697335]
# csv index: [0] score: [-0.3315228]
# csv index: [0] score: [-0.3433149]
# csv index: [0] score: [-0.29697335]
# csv index: [0] score: [-0.3433149]
# csv index: [0] score: [-0.3315228]
# csv index: [0] score: [-0.3315228]
# Results for Pantry
# csv index: 0 score: -0.0
# Results for Furniture
# csv index: [0] score: [-0.3609017]
# csv index: [0] score: [-0.37406188]
# csv index: [0] score: [-0.33099845]
# csv index: [0] score: [-0.35067993]
# csv index: [0] score: [-0.37342572]
# csv index: [0] score: [-0.31541306]
# csv index: [0] score: [-0.43537483]
# csv index: [0] score: [-0.38293922]
# csv index: [0] score: [-0.33888936]
# csv index: [0] score: [-0.46412125]
# Results for PC Games
# csv index: 0 score: -0.0
# Results for All Appliances
# csv index: [0] score: [-0.]
# csv index: [0] score: [-0.]
# csv index: [0] score: [-0.]
# csv index: [0] score: [-0.]
# csv index: [0] score: [-0.]
# csv index: [0] score: [-0.]
# csv index: [0] score: [-0.]
# csv index: [0] score: [-0.]
# csv index: [0] score: [-0.]
# csv index: [0] score: [-0.]
# Results for Gaming Accessories
# csv index: 0 score: -0.0
# Results for Personal Care Appliances
# csv index: [0] score: [-0.3695286]
# csv index: [0] score: [-0.49679896]
# csv index: [0] score: [-0.39982495]
# csv index: [0] score: [-0.39502296]
# csv index: [0] score: [-0.353153]
# csv index: [0] score: [-0.36663884]
# csv index: [0] score: [-0.36031878]
# csv index: [0] score: [-0.46974635]
# csv index: [0] score: [-0.31114268]
# csv index: [0] score: [-0.34886944]
# Results for Gaming Consoles
# csv index: 0 score: -0.0
# Results for Cameras
# csv index: [0] score: [-0.3253225]
# csv index: [0] score: [-0.30665854]
# csv index: [0] score: [-0.36997294]
# csv index: [0] score: [-0.28235808]
# csv index: [0] score: [-0.2320257]
# csv index: [0] score: [-0.36119857]
# csv index: [0] score: [-0.30057484]
# csv index: [0] score: [-0.37762842]
# csv index: [0] score: [-0.29950893]
# csv index: [0] score: [-0.32409728]
# Results for Refrigerators
# csv index: [0] score: [-0.345749]
# csv index: [0] score: [-0.345749]
# csv index: [0] score: [-0.36616898]
# csv index: [0] score: [-0.35853106]
# csv index: [0] score: [-0.29777664]
# csv index: [0] score: [-0.362468]
# csv index: [0] score: [-0.38189423]
# csv index: [0] score: [-0.35696808]
# csv index: [0] score: [-0.3813353]
# csv index: [0] score: [-0.3706411]
# Results for Baby Bath Skin and Grooming
# csv index: [0] score: [-0.39861584]
# csv index: [0] score: [-0.2735223]
# csv index: [0] score: [-0.3394033]
# csv index: [0] score: [-0.38157722]
# csv index: [0] score: [-0.32766062]
# csv index: [0] score: [-0.39139807]
# csv index: [0] score: [-0.39374623]
# csv index: [0] score: [-0.3296042]
# csv index: [0] score: [-0.38092953]
# csv index: [0] score: [-0.404554]
# Results for Garden and Outdoors
# csv index: [0] score: [-0.3922246]
# csv index: [0] score: [-0.5489142]
# csv index: [0] score: [-0.4103733]
# csv index: [0] score: [-0.51225626]
# csv index: [0] score: [-0.5930917]
# csv index: [0] score: [-0.5305125]
# csv index: [0] score: [-0.30819044]
# csv index: [0] score: [-0.59276676]
# csv index: [0] score: [-0.6270056]
# csv index: [0] score: [-0.36897624]
# Results for Refurbished and Open Box
# csv index: [0] score: [-0.34064472]
# csv index: [0] score: [-0.36759493]
# csv index: [0] score: [-0.40555117]
# csv index: [0] score: [-0.5251072]
# csv index: [0] score: [-0.39641583]
# csv index: [0] score: [-0.34219185]
# csv index: [0] score: [-0.3566404]
# csv index: [0] score: [-0.39634073]
# csv index: [0] score: [-0.38189396]
# csv index: [0] score: [-0.37627363]
# Results for Gold and Diamond Jewellery
# csv index: [0] score: [-0.]
# csv index: [0] score: [-0.]
# csv index: [0] score: [-0.]
# csv index: [0] score: [-0.]
# csv index: [0] score: [-0.]
# csv index: [0] score: [-0.]
# csv index: [0] score: [-0.]
# csv index: [0] score: [-0.]
# csv index: [0] score: [-0.]
# csv index: [0] score: [-0.]
# Results for Rucksacks
# csv index: [0] score: [-0.]
# csv index: [0] score: [-0.]
# csv index: [0] score: [-0.]
# csv index: [0] score: [-0.]
# csv index: [0] score: [-0.]
# csv index: [0] score: [-0.]
# csv index: [0] score: [-0.]
# csv index: [0] score: [-0.]
# csv index: [0] score: [-0.]
# csv index: [0] score: [-0.]
# Results for Handbags and Clutches
# csv index: [0] score: [-0.]
# csv index: [0] score: [-0.]
# csv index: [0] score: [-0.]
# csv index: [0] score: [-0.]
# csv index: [0] score: [-0.]
# csv index: [0] score: [-0.]
# csv index: [0] score: [-0.]
# csv index: [0] score: [-0.]
# csv index: [0] score: [-0.]
# csv index: [0] score: [-0.]
# Results for Running
# csv index: [0] score: [-0.40164647]
# csv index: [0] score: [-0.36361834]
# csv index: [0] score: [-0.40234247]
# csv index: [0] score: [-0.3756127]
# csv index: [0] score: [-0.38229698]
# csv index: [0] score: [-0.37674245]
# csv index: [0] score: [-0.40215576]
# csv index: [0] score: [-0.382385]
# csv index: [0] score: [-0.5281335]
# csv index: [0] score: [-0.4457249]

# %%
# import os
# import h5py
# import numpy as np
# import pandas as pd
# from sklearn.metrics.pairwise import cosine_similarity
# import matplotlib.pyplot as plt
# import requests
# from io import BytesIO
# from PIL import Image
# 
# # Path to the folder containing HDF5 files
# folder_path = 'images'
# # Path to the folder containing CSV files with image links
# csv_folder_path = r'..\Datasets'
# 
# # Initialize an empty list to store embeddings and image links
# all_embeddings = []
# image_links = []
# 
# 
# def _list_datasets(file_path):
#     """List all dataset names in an HDF5 file."""
#     with h5py.File(file_path, 'r') as hdf:
#         return [name for name in hdf.keys()]
# 
# 
# # Iterate through each file in the folder
# for file_name in os.listdir(folder_path):
#     # if the hdf5 file is dataset.hdf5, continue
#     if file_name.endswith('.hdf5'):
#         file_path = os.path.join(folder_path, file_name)
#         csv_file_path = os.path.join(csv_folder_path, file_name.replace('.hdf5', '.csv'))
# 
#         dataset_names = _list_datasets(file_path)
# 
#         with h5py.File(file_path, 'r') as hdf:
#             # Read the corresponding CSV file to get image links
#             df = pd.read_csv(csv_file_path)
#             for dataset_name in dataset_names:
#                 embeddings = hdf[dataset_name][:]
#                 if embeddings.size > 0:
#                     # Detect the actual embedding size
#                     actual_embedding_size = embeddings.shape[-1]
#                     for i, embedding in enumerate(embeddings):
#                         all_embeddings.append(embedding)
#                         image_links.append(df['image'].iloc[i])
#                 else:
#                     all_embeddings.append(np.zeros(actual_embedding_size))  # Handle empty embeddings case
#                     image_links.append(None)  # Handle empty embeddings case
# 
# # Convert lists to NumPy arrays
# all_embeddings = np.array(all_embeddings)
# image_links = np.array(image_links)
# 
# # Ensure the embeddings array is 2-dimensional
# all_embeddings = all_embeddings.reshape(all_embeddings.shape[0], -1)
# 
# # Save the concatenated embeddings and image links as NumPy arrays
# np.save('all_embeddings.npy', all_embeddings)
# np.save('image_links.npy', image_links)
# 
# # Create a query embedding (using the first embedding as an example)
# query_product_embedding = np.load('sunflower/sunflower1.npy')
# 
# # Calculate cosine similarities
# similarities = cosine_similarity(query_product_embedding.reshape(1, -1), all_embeddings).flatten()
# 
# # Get indices of top 10 closest embeddings
# top_10_indices = np.argsort(-similarities)[:10]
# 
# # Display the top 10 closest images
# fig, axes = plt.subplots(2, 5, figsize=(15, 6))
# axes = axes.flatten()
# 
# for ax, idx in zip(axes, top_10_indices):
#     image_link = image_links[idx]
#     if image_link:
#         response = requests.get(image_link)
#         img = Image.open(BytesIO(response.content))
#         ax.imshow(img)
#     else:
#         ax.text(0.5, 0.5, 'No Image', horizontalalignment='center', verticalalignment='center')
#     ax.axis('off')
#     ax.set_title(f'Similarity: {similarities[idx]:.4f}')
# 
# plt.tight_layout()
# plt.show()

# %% [markdown]
# # imports

# %%
import os
import h5py
import numpy as np
import pandas as pd
from sklearn.metrics.pairwise import cosine_similarity
import matplotlib.pyplot as plt
import requests
from io import BytesIO
from PIL import Image
from vgg.VGG import get_image_embeddings, load_image_bytes, load_image, get_score, label

# %% [markdown]
# # directories

# %%
# Path to the folder containing HDF5 files
hdf5_folder_path = 'images'
# Path to the folder containing CSV files with image links
csv_folder_path = r'..\Datasets'

# %% [markdown]
# # functions

# %%
def get_embedding_links(return_dict=False):
    # Initialize an empty list to store embeddings and image links
    all_embeddings = []
    image_links = []

    def _list_datasets(file_path):
        """List all dataset names in an HDF5 file."""
        with h5py.File(file_path, 'r') as hdf:
            return [name for name in hdf.keys()]

    # Iterate through each file in the folder
    for file_name in os.listdir(hdf5_folder_path):
        # if the hdf5 file is dataset.hdf5, continue
        if file_name.endswith('.hdf5'):
            file_path = os.path.join(hdf5_folder_path, file_name)
            csv_file_path = os.path.join(csv_folder_path, file_name.replace('.hdf5', '.csv'))

            dataset_names = _list_datasets(file_path)

            with h5py.File(file_path, 'r') as hdf:
                # Read the corresponding CSV file to get image links
                df = pd.read_csv(csv_file_path)
                for dataset_name in dataset_names:
                    embeddings = hdf[dataset_name][:]
                    if embeddings.size > 0:
                        # Detect the actual embedding size
                        actual_embedding_size = embeddings.shape[-1]
                        for i, embedding in enumerate(embeddings):
                            all_embeddings.append(embedding)
                            image_links.append(df['image'].iloc[i])
                    else:
                        all_embeddings.append(np.zeros(actual_embedding_size))  # Handle empty embeddings case
                        image_links.append(None)  # Handle empty embeddings case

    # Convert lists to NumPy arrays
    all_embeddings = np.array(all_embeddings)
    image_links = np.array(image_links)

    # Ensure the embeddings array is 2-dimensional
    all_embeddings = all_embeddings.reshape(all_embeddings.shape[0], -1)

    if return_dict:
        # create a dictionary with embeddings to image links
        embedding_links_dict = {}
        for i in range(len(all_embeddings)):
            embedding_links_dict[tuple(all_embeddings[i])] = image_links[i]
        return embedding_links_dict

    return all_embeddings, image_links

# %%
def get_cosine_similarities(query_embedding, all_embeddings, k=0):
    # Calculate cosine similarities
    similarities = cosine_similarity(query_embedding.reshape(1, -1), all_embeddings).flatten()
    if k > 0:
        if k > len(similarities):
            print(f"Warning: k is larger than the number of embeddings. Setting k to {len(similarities)}")
            k = len(similarities)

        # Get indices of top k closest embeddings
        top_k_indices = np.argsort(-similarities)[:k]
        return similarities, top_k_indices
    return similarities

# %%
# Display the top 10 closest images
fig, axes = plt.subplots(2, 5, figsize=(15, 6))
axes = axes.flatten()

# input_img_path = "evaluation_images/bottle.png"
# input_img = load_image(input_img_path)
# input_embedding = get_image_embeddings(input_img)
# np.save("bottle.npy", input_embedding)

query_product_embedding = np.load('bottle.npy')
all_embeddings, image_links = get_embedding_links()
similarities, top_10_indices = get_cosine_similarities(query_product_embedding, all_embeddings, k=10)

for ax, idx in zip(axes, top_10_indices):
    image_link = image_links[idx]
    if image_link:
        response = requests.get(image_link)
        img = Image.open(BytesIO(response.content))
        ax.imshow(img)
    else:
        ax.text(0.5, 0.5, 'No Image', horizontalalignment='center', verticalalignment='center')
    ax.axis('off')
    ax.set_title(f'Similarity: {similarities[idx]:.4f}')

plt.tight_layout()
plt.show()
