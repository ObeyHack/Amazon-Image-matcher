# %% [markdown]
# # Requirements

# %%
from VGG import get_image_embeddings, get_similarity_score, load_image
import matplotlib.pyplot as plt
import matplotlib.image as mpimg

# %% [markdown]
# # Load Image

# %%
def show_image(image_path):
  image = mpimg.imread(image_path)
  imgplot = plt.imshow(image)
  plt.show()

# %%
sunflower = 'sunflower/sunflower1.jpg'
helianthus = 'sunflower/sunflower2.jpg'
image1 = load_image(sunflower)
image2 = load_image(helianthus)

# %% [markdown]
# # Image 1

# %%
show_image(sunflower)

# %% [markdown]
# # Image 2

# %%
show_image(helianthus)

# %% [markdown]
# # Image Embeddings

# %%
image1_embedding = get_image_embeddings(image1)
print(image1_embedding)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 299ms/step
# [[1.84517231e+01 0.00000000e+00 4.39533882e+01 5.93006172e+01
#   1.55951691e+01 0.00000000e+00 3.91597404e+01 6.73104858e+01
#   0.00000000e+00 1.36753035e+01 1.59053507e+01 0.00000000e+00
#   2.56164742e+00 0.00000000e+00 4.45667191e+01 6.29723129e+01
#   0.00000000e+00 1.37836132e+01 0.00000000e+00 8.60344887e+00
#   0.00000000e+00 8.21185589e+00 0.00000000e+00 1.23601913e+02
#   3.50714326e+00 5.28712387e+01 0.00000000e+00 1.57841623e-01
#   5.67525940e+01 0.00000000e+00 5.40154636e-01 0.00000000e+00
#   2.49130955e+01 2.07600384e+01 1.19790211e+01 0.00000000e+00
#   3.34525943e+00 0.00000000e+00 0.00000000e+00 1.42777243e+01
#   2.67195702e+00 6.55138159e+00 1.19383383e+01 1.01338844e+02
#   8.26481552e+01 5.99601698e+00 2.02517891e+01 2.41858406e+01
#   4.06546326e+01 3.27319984e+01 5.46602440e+00 4.48122253e+01
#   2.40949402e+01 5.45089569e+01 1.13943644e+01 0.00000000e+00
# ...

# %% [markdown]
# # Similarity Score

# %%
get_similarity_score(image1, image2)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 223ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 243ms/step
# array([0.80104905], dtype=float32)
